# %% [markdown]
# # Pandas DataFrame

# %%
import pandas as pd

# %% [markdown]
# # Creating dataframe from dictionary data structure

# %%
df = pd.DataFrame({'Name':['Ajay','Akash','Sanjay','Anil'],
                   'Age':[17,18,19,20],'occupation':['doctor','engineer','student','lawyer']})

# %%
df
# Out:
#      Name  Age occupation
# 0    Ajay   17     doctor
# 1   Akash   18   engineer
# 2  Sanjay   19    student
# 3    Anil   20     lawyer

# %%
print(df)
# Out:
#      Name  Age occupation
# 0    Ajay   17     doctor
# 1   Akash   18   engineer
# 2  Sanjay   19    student
# 3    Anil   20     lawyer

# %% [markdown]
# # Importing CSV data from pandas library

# %%
testing = pd.read_csv('test.csv')

# %%
testing
# Out:
#    id name  salary
# 0   1  'a'      10
# 1   2  'b'      11
# 2   3  'c'      12

# %%
type(testing)
# Out:
# pandas.core.frame.DataFrame

# %%
testing.shape
# Out:
# (3, 3)

# %%
testing.index
# Out:
# RangeIndex(start=0, stop=3, step=1)

# %%
insurance_df= pd.read_csv('insurance_training.csv')

# %%
insurance_df
# Out:
#       Unnamed: 0  age  sex     bmi  children  smoker  region  BMI_group  \
# 0            560   46    0  19.950         2       0       1          1
# 1           1285   47    0  24.320         0       0       0          1
# 2           1142   52    0  24.860         0       0       2          1
# 3            969   39    0  34.320         5       0       2          2
# 4            486   54    0  21.470         3       0       1          1
# 5            170   63    1  41.470         0       0       2          2
# 6            277   22    0  24.300         0       0       3          1
# 7           1033   18    1  21.565         0       1       0          1
# 8            209   40    1  41.230         1       0       0          2
# 9            947   37    1  34.200         1       1       0          2
# 10           140   34    1  22.420         2       0       0          1
# 11          1140   50    1  37.070         1       0       2          2
# ...

# %%
insurance_df.shape
# Out:
# (1070, 9)

# %% [markdown]
# # Reading and summarizing dataframes

# %%
insurance_df.head()
# Out:
#    Unnamed: 0  age  sex    bmi  children  smoker  region  BMI_group  \
# 0         560   46    0  19.95         2       0       1          1
# 1        1285   47    0  24.32         0       0       0          1
# 2        1142   52    0  24.86         0       0       2          1
# 3         969   39    0  34.32         5       0       2          2
# 4         486   54    0  21.47         3       0       1          1
#
#        charges
# 0   9193.83850
# 1   8534.67180
# 2  27117.99378
# 3   8596.82780
# 4  12475.35130

# %%
insurance_df.head(2)
# Out:
#    Unnamed: 0  age  sex    bmi  children  smoker  region  BMI_group    charges
# 0         560   46    0  19.95         2       0       1          1  9193.8385
# 1        1285   47    0  24.32         0       0       0          1  8534.6718

# %%
insurance_df.tail()
# Out:
#       Unnamed: 0  age  sex     bmi  children  smoker  region  BMI_group  \
# 1065        1095   18    0  31.350         4       0       0          2
# 1066        1130   39    0  23.870         5       0       2          1
# 1067        1294   58    1  25.175         0       0       0          3
# 1068         860   37    0  47.600         2       1       3          2
# 1069        1126   55    1  29.900         0       0       3          3
#
#           charges
# 1065   4561.18850
# 1066   8582.30230
# 1067  11931.12525
# 1068  46113.51100
# 1069  10214.63600

# %%
insurance_df.tail(3)
# Out:
#       Unnamed: 0  age  sex     bmi  children  smoker  region  BMI_group  \
# 1067        1294   58    1  25.175         0       0       0          3
# 1068         860   37    0  47.600         2       1       3          2
# 1069        1126   55    1  29.900         0       0       3          3
#
#           charges
# 1067  11931.12525
# 1068  46113.51100
# 1069  10214.63600

# %%
#look at datatype of each column using info command

insurance_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1070 entries, 0 to 1069
# Data columns (total 9 columns):
# Unnamed: 0    1070 non-null int64
# age           1070 non-null int64
# sex           1070 non-null int64
# bmi           1070 non-null float64
# children      1070 non-null int64
# smoker        1070 non-null int64
# region        1070 non-null int64
# BMI_group     1070 non-null int64
# charges       1070 non-null float64
# dtypes: float64(2), int64(7)
# memory usage: 75.3 KB

# %%
# Describe command is used to give you summary statistics of your numerical columns
insurance_df.describe()
# Out:
#         Unnamed: 0          age          sex          bmi     children  \
# count  1070.000000  1070.000000  1070.000000  1070.000000  1070.000000
# mean    666.579439    39.357009     0.512150    30.560397     1.107477
# std     386.312762    14.073960     0.500086     6.043386     1.215983
# min       0.000000    18.000000     0.000000    15.960000     0.000000
# 25%     332.250000    27.000000     0.000000    26.205000     0.000000
# 50%     670.000000    39.500000     1.000000    30.210000     1.000000
# 75%    1002.750000    51.000000     1.000000    34.496250     2.000000
# max    1337.000000    64.000000     1.000000    53.130000     5.000000
#
#             smoker       region    BMI_group       charges
# count  1070.000000  1070.000000  1070.000000   1070.000000
# mean      0.205607     1.508411     2.119626  13346.089736
# std       0.404334     1.115175     0.721634  12019.510778
# min       0.000000     0.000000     0.000000   1121.873900
# ...

# %%
insurance_df.columns
# Out:
# Index(['Unnamed: 0', 'age', 'sex', 'bmi', 'children', 'smoker', 'region',
#        'BMI_group', 'charges'],
#       dtype='object')

# %%
insurance_df.shape
# Out:
# (1070, 9)

# %%
insurance_df.values
# Out:
# array([[5.60000000e+02, 4.60000000e+01, 0.00000000e+00, ...,
#         1.00000000e+00, 1.00000000e+00, 9.19383850e+03],
#        [1.28500000e+03, 4.70000000e+01, 0.00000000e+00, ...,
#         0.00000000e+00, 1.00000000e+00, 8.53467180e+03],
#        [1.14200000e+03, 5.20000000e+01, 0.00000000e+00, ...,
#         2.00000000e+00, 1.00000000e+00, 2.71179938e+04],
#        ...,
#        [1.29400000e+03, 5.80000000e+01, 1.00000000e+00, ...,
#         0.00000000e+00, 3.00000000e+00, 1.19311252e+04],
#        [8.60000000e+02, 3.70000000e+01, 0.00000000e+00, ...,
#         3.00000000e+00, 2.00000000e+00, 4.61135110e+04],
#        [1.12600000e+03, 5.50000000e+01, 1.00000000e+00, ...,
#         3.00000000e+00, 3.00000000e+00, 1.02146360e+04]])

# %%
insurance_df
# Out:
#       Unnamed: 0  age  sex     bmi  children  smoker  region  BMI_group  \
# 0            560   46    0  19.950         2       0       1          1
# 1           1285   47    0  24.320         0       0       0          1
# 2           1142   52    0  24.860         0       0       2          1
# 3            969   39    0  34.320         5       0       2          2
# 4            486   54    0  21.470         3       0       1          1
# 5            170   63    1  41.470         0       0       2          2
# 6            277   22    0  24.300         0       0       3          1
# 7           1033   18    1  21.565         0       1       0          1
# 8            209   40    1  41.230         1       0       0          2
# 9            947   37    1  34.200         1       1       0          2
# 10           140   34    1  22.420         2       0       0          1
# 11          1140   50    1  37.070         1       0       2          2
# ...

# %%
# set dataframe column as index

insurance_df.set_index('Unnamed: 0', inplace=True)
insurance_df.head()
# Out:
#             age  sex    bmi  children  smoker  region  BMI_group      charges
# Unnamed: 0
# 560          46    0  19.95         2       0       1          1   9193.83850
# 1285         47    0  24.32         0       0       0          1   8534.67180
# 1142         52    0  24.86         0       0       2          1  27117.99378
# 969          39    0  34.32         5       0       2          2   8596.82780
# 486          54    0  21.47         3       0       1          1  12475.35130

# %% [markdown]
# # dataframe sorting

# %%
insurance_df.sort_index(axis=0,ascending=False)
# Out:
#             age  sex     bmi  children  smoker  region  BMI_group      charges
# Unnamed: 0
# 1337         61    0  29.070         0       1       1          3  29141.36030
# 1336         21    0  25.800         0       0       3          3   2007.94500
# 1335         18    0  36.850         0       0       2          2   1629.83350
# 1334         18    0  31.920         0       0       0          2   2205.98080
# 1333         50    1  30.970         3       0       1          2  10600.54830
# 1332         52    0  44.700         3       0       3          2  11411.68500
# 1331         23    0  33.400         0       0       3          2  10795.93733
# 1330         57    0  25.740         2       0       2          3  12629.16560
# 1329         52    1  38.600         2       0       3          2  10325.20600
# 1328         23    0  24.225         2       0       0          1  22395.74424
# 1326         42    0  32.870         0       0       0          2   7050.02130
# ...

# %%
# sort data frame columns by values

insurance_df.sort_values(by='charges').head()
# Out:
#             age  sex    bmi  children  smoker  region  BMI_group    charges
# Unnamed: 0
# 940          18    1  23.21         0       0       2          1  1121.8739
# 1244         18    1  33.33         0       0       2          2  1135.9407
# 663          18    1  33.66         0       0       2          2  1136.3994
# 22           18    1  34.10         0       0       2          2  1137.0110
# 194          18    1  34.43         0       0       2          2  1137.4697

# %%
insurance_df.sort_values(by='bmi',ascending=False).head()
# Out:
#             age  sex    bmi  children  smoker  region  BMI_group     charges
# Unnamed: 0
# 1317         18    1  53.13         0       0       2          2   1163.4627
# 847          23    1  50.38         1       0       2          2   2438.0552
# 116          58    1  49.06         0       0       2          2  11381.3254
# 1088         52    1  47.74         1       0       2          2   9748.9106
# 860          37    0  47.60         2       1       3          2  46113.5110

# %%
insurance_df.sort_values(by=['age','charges'],ascending=False)
# Out:
#             age  sex     bmi  children  smoker  region  BMI_group      charges
# Unnamed: 0
# 1241         64    1  36.960         2       1       2          2  49577.66240
# 328          64    0  33.800         1       1       3          2  47928.03000
# 94           64    0  31.300         2       1       3          2  47291.05500
# 420          64    1  33.880         0       1       2          2  46889.26120
# 62           64    1  24.700         1       0       1          1  30166.61817
# 1265         64    1  23.760         0       1       2          1  26926.51440
# 378          64    0  30.115         3       0       1          2  16455.70785
# 603          64    0  39.050         3       0       2          2  16085.12750
# 825          64    0  31.825         2       0       0          2  16069.08475
# 199          64    0  39.330         0       0       0          2  14901.51670
# 402          64    0  32.965         0       0       1          2  14692.66935
# ...

# %% [markdown]
# # Tab completion

# %% [markdown]
# # Selecting columns

# %%
#selecting 1 column
insurance_df['age']
# Out:
# Unnamed: 0
# 560     46
# 1285    47
# 1142    52
# 969     39
# 486     54
# 170     63
# 277     22
# 1033    18
# 209     40
# 947     37
# 140     34
# 1140    50
# 1106    49
# 199     64
# 932     46
# 316     50
# 1207    36
# 10      25
# 147     51
# 1240    52
# 282     30
# 477     25
# 1334    18
# 859     57
# 380     27
# 390     48
# 425     45
# 892     54
# 481     49
# 990     26
#         ..
# 510     56
# 1082    38
# 474     54
# 856     48
# 747     19
# 252     54
# 21      30
# 459     40
# 1184    23
# 276     19
# 955     31
# 1215    18
# 385     19
# 805     45
# 343     63
# 769     38
# 130     59
# 871     26
# 1123    27
# 87      56
# 330     61
# 1238    37
# 466     60
# 121     18
# 1044    55
# 1095    18
# 1130    39
# 1294    58
# 860     37
# 1126    55
# Name: age, Length: 1070, dtype: int64

# %%
type(insurance_df['age'])
# Out:
# pandas.core.series.Series

# %%
# select multiple columns
insurance_df[['age','bmi']].head()
# Out:
#             age    bmi
# Unnamed: 0
# 560          46  19.95
# 1285         47  24.32
# 1142         52  24.86
# 969          39  34.32
# 486          54  21.47

# %%
type(insurance_df[['age','bmi']].head())
# Out:
# pandas.core.frame.DataFrame

# %%
insurance_df
# Out:
#             age  sex     bmi  children  smoker  region  BMI_group      charges
# Unnamed: 0
# 560          46    0  19.950         2       0       1          1   9193.83850
# 1285         47    0  24.320         0       0       0          1   8534.67180
# 1142         52    0  24.860         0       0       2          1  27117.99378
# 969          39    0  34.320         5       0       2          2   8596.82780
# 486          54    0  21.470         3       0       1          1  12475.35130
# 170          63    1  41.470         0       0       2          2  13405.39030
# 277          22    0  24.300         0       0       3          1   2150.46900
# 1033         18    1  21.565         0       1       0          1  13747.87235
# 209          40    1  41.230         1       0       0          2   6610.10970
# 947          37    1  34.200         1       1       0          2  39047.28500
# 140          34    1  22.420         2       0       0          1  27375.90478
# ...

# %%
# restricting total number of rows in a dataframe
pd.get_option("display.max_rows")
# Out:
# 60

# %%
pd.set_option("display.max_rows",10)

# %%
insurance_df
# Out:
#             age  sex     bmi  children  smoker  region  BMI_group      charges
# Unnamed: 0
# 560          46    0  19.950         2       0       1          1   9193.83850
# 1285         47    0  24.320         0       0       0          1   8534.67180
# 1142         52    0  24.860         0       0       2          1  27117.99378
# 969          39    0  34.320         5       0       2          2   8596.82780
# 486          54    0  21.470         3       0       1          1  12475.35130
# ...         ...  ...     ...       ...     ...     ...        ...          ...
# 1095         18    0  31.350         4       0       0          2   4561.18850
# 1130         39    0  23.870         5       0       2          1   8582.30230
# 1294         58    1  25.175         0       0       0          3  11931.12525
# 860          37    0  47.600         2       1       3          2  46113.51100
# 1126         55    1  29.900         0       0       3          3  10214.63600
#
# ...

# %%
#restrict total number of columns in a dataframe
pd.get_option("display.max_columns")
# Out:
# 20

# %%
insurance_df
# Out:
#             age  sex     bmi  children  smoker  region  BMI_group      charges
# Unnamed: 0
# 560          46    0  19.950         2       0       1          1   9193.83850
# 1285         47    0  24.320         0       0       0          1   8534.67180
# 1142         52    0  24.860         0       0       2          1  27117.99378
# 969          39    0  34.320         5       0       2          2   8596.82780
# 486          54    0  21.470         3       0       1          1  12475.35130
# ...         ...  ...     ...       ...     ...     ...        ...          ...
# 1095         18    0  31.350         4       0       0          2   4561.18850
# 1130         39    0  23.870         5       0       2          1   8582.30230
# 1294         58    1  25.175         0       0       0          3  11931.12525
# 860          37    0  47.600         2       1       3          2  46113.51100
# 1126         55    1  29.900         0       0       3          3  10214.63600
#
# ...

# %%
type(insurance_df[['age']])
# Out:
# pandas.core.frame.DataFrame

# %%
# selecting columns using dot notation

insurance_df.age
# Out:
# Unnamed: 0
# 560     46
# 1285    47
# 1142    52
# 969     39
# 486     54
#         ..
# 1095    18
# 1130    39
# 1294    58
# 860     37
# 1126    55
# Name: age, Length: 1070, dtype: int64

# %%
insurance_df.age.equals(insurance_df['age'])
# Out:
# True

# %%
insurance_df
# Out:
#             age  sex     bmi  children  smoker  region  BMI_group      charges
# Unnamed: 0
# 560          46    0  19.950         2       0       1          1   9193.83850
# 1285         47    0  24.320         0       0       0          1   8534.67180
# 1142         52    0  24.860         0       0       2          1  27117.99378
# 969          39    0  34.320         5       0       2          2   8596.82780
# 486          54    0  21.470         3       0       1          1  12475.35130
# ...         ...  ...     ...       ...     ...     ...        ...          ...
# 1095         18    0  31.350         4       0       0          2   4561.18850
# 1130         39    0  23.870         5       0       2          1   8582.30230
# 1294         58    1  25.175         0       0       0          3  11931.12525
# 860          37    0  47.600         2       1       3          2  46113.51100
# 1126         55    1  29.900         0       0       3          3  10214.63600
#
# ...

# %% [markdown]
# # Position based indexing and slicing

# %%
#1st row
insurance_df.iloc[0]
# Out:
# age            46.0000
# sex             0.0000
# bmi            19.9500
# children        2.0000
# smoker          0.0000
# region          1.0000
# BMI_group       1.0000
# charges      9193.8385
# Name: 560, dtype: float64

# %%
type(insurance_df.iloc[0])
# Out:
# pandas.core.series.Series

# %%
#2nd row
insurance_df.iloc[1]
# Out:
# age            47.0000
# sex             0.0000
# bmi            24.3200
# children        0.0000
# smoker          0.0000
# region          0.0000
# BMI_group       1.0000
# charges      8534.6718
# Name: 1285, dtype: float64

# %%
#last row
insurance_df.iloc[-1]
# Out:
# age             55.000
# sex              1.000
# bmi             29.900
# children         0.000
# smoker           0.000
# region           3.000
# BMI_group        3.000
# charges      10214.636
# Name: 1126, dtype: float64

# %%
#rows at index position 1,2,3

insurance_df.iloc[[1,2,3]]
# Out:
#             age  sex    bmi  children  smoker  region  BMI_group      charges
# Unnamed: 0
# 1285         47    0  24.32         0       0       0          1   8534.67180
# 1142         52    0  24.86         0       0       2          1  27117.99378
# 969          39    0  34.32         5       0       2          2   8596.82780

# %%
#top 5 rows
insurance_df.iloc[:5]
# Out:
#             age  sex    bmi  children  smoker  region  BMI_group      charges
# Unnamed: 0
# 560          46    0  19.95         2       0       1          1   9193.83850
# 1285         47    0  24.32         0       0       0          1   8534.67180
# 1142         52    0  24.86         0       0       2          1  27117.99378
# 969          39    0  34.32         5       0       2          2   8596.82780
# 486          54    0  21.47         3       0       1          1  12475.35130

# %%
#last 5 rows
insurance_df.iloc[-5:]
# Out:
#             age  sex     bmi  children  smoker  region  BMI_group      charges
# Unnamed: 0
# 1095         18    0  31.350         4       0       0          2   4561.18850
# 1130         39    0  23.870         5       0       2          1   8582.30230
# 1294         58    1  25.175         0       0       0          3  11931.12525
# 860          37    0  47.600         2       1       3          2  46113.51100
# 1126         55    1  29.900         0       0       3          3  10214.63600

# %%
#all rows
insurance_df.iloc[:]
# Out:
#             age  sex     bmi  children  smoker  region  BMI_group      charges
# Unnamed: 0
# 560          46    0  19.950         2       0       1          1   9193.83850
# 1285         47    0  24.320         0       0       0          1   8534.67180
# 1142         52    0  24.860         0       0       2          1  27117.99378
# 969          39    0  34.320         5       0       2          2   8596.82780
# 486          54    0  21.470         3       0       1          1  12475.35130
# ...         ...  ...     ...       ...     ...     ...        ...          ...
# 1095         18    0  31.350         4       0       0          2   4561.18850
# 1130         39    0  23.870         5       0       2          1   8582.30230
# 1294         58    1  25.175         0       0       0          3  11931.12525
# 860          37    0  47.600         2       1       3          2  46113.51100
# 1126         55    1  29.900         0       0       3          3  10214.63600
#
# ...

# %% [markdown]
# # slicing of rows and columns with iloc

# %%
insurance_df.iloc[0,7]
# Out:
# 9193.8385

# %%
#first row and out of that first 3 columns
insurance_df.iloc[0,:3]
# Out:
# age    46.00
# sex     0.00
# bmi    19.95
# Name: 560, dtype: float64

# %%
#first row and column at index 1,3,5
insurance_df.iloc[0,[1,3,5]]
# Out:
# sex         0.0
# children    2.0
# region      1.0
# Name: 560, dtype: float64

# %%
# select top 3 rows and columns corresponding to those rows at index 1,3,5
insurance_df.iloc[:3,[1,3,5]]
# Out:
#             sex  children  region
# Unnamed: 0
# 560           0         2       1
# 1285          0         0       0
# 1142          0         0       2

# %%
insurance_df
# Out:
#             age  sex     bmi  children  smoker  region  BMI_group      charges
# Unnamed: 0
# 560          46    0  19.950         2       0       1          1   9193.83850
# 1285         47    0  24.320         0       0       0          1   8534.67180
# 1142         52    0  24.860         0       0       2          1  27117.99378
# 969          39    0  34.320         5       0       2          2   8596.82780
# 486          54    0  21.470         3       0       1          1  12475.35130
# ...         ...  ...     ...       ...     ...     ...        ...          ...
# 1095         18    0  31.350         4       0       0          2   4561.18850
# 1130         39    0  23.870         5       0       2          1   8582.30230
# 1294         58    1  25.175         0       0       0          3  11931.12525
# 860          37    0  47.600         2       1       3          2  46113.51100
# 1126         55    1  29.900         0       0       3          3  10214.63600
#
# ...

# %%
insurance_df.index.names=['ID']

# %%
insurance_df
# Out:
#       age  sex     bmi  children  smoker  region  BMI_group      charges
# ID
# 560    46    0  19.950         2       0       1          1   9193.83850
# 1285   47    0  24.320         0       0       0          1   8534.67180
# 1142   52    0  24.860         0       0       2          1  27117.99378
# 969    39    0  34.320         5       0       2          2   8596.82780
# 486    54    0  21.470         3       0       1          1  12475.35130
# ...   ...  ...     ...       ...     ...     ...        ...          ...
# 1095   18    0  31.350         4       0       0          2   4561.18850
# 1130   39    0  23.870         5       0       2          1   8582.30230
# 1294   58    1  25.175         0       0       0          3  11931.12525
# 860    37    0  47.600         2       1       3          2  46113.51100
# 1126   55    1  29.900         0       0       3          3  10214.63600
#
# [1070 rows x 8 columns]

# %%
# rename a particular index
insurance_df.rename(index={1126:9999})
# Out:
#       age  sex     bmi  children  smoker  region  BMI_group      charges
# ID
# 560    46    0  19.950         2       0       1          1   9193.83850
# 1285   47    0  24.320         0       0       0          1   8534.67180
# 1142   52    0  24.860         0       0       2          1  27117.99378
# 969    39    0  34.320         5       0       2          2   8596.82780
# 486    54    0  21.470         3       0       1          1  12475.35130
# ...   ...  ...     ...       ...     ...     ...        ...          ...
# 1095   18    0  31.350         4       0       0          2   4561.18850
# 1130   39    0  23.870         5       0       2          1   8582.30230
# 1294   58    1  25.175         0       0       0          3  11931.12525
# 860    37    0  47.600         2       1       3          2  46113.51100
# 9999   55    1  29.900         0       0       3          3  10214.63600
#
# [1070 rows x 8 columns]

# %%
#renaming a particular column
insurance_df.rename(columns={'charges':'charge'},inplace=True)

# %% [markdown]
# # Label based indexing and slicing with loc function

# %%
insurance_df
# Out:
#       age  sex     bmi  children  smoker  region  BMI_group       charge
# ID
# 560    46    0  19.950         2       0       1          1   9193.83850
# 1285   47    0  24.320         0       0       0          1   8534.67180
# 1142   52    0  24.860         0       0       2          1  27117.99378
# 969    39    0  34.320         5       0       2          2   8596.82780
# 486    54    0  21.470         3       0       1          1  12475.35130
# ...   ...  ...     ...       ...     ...     ...        ...          ...
# 1095   18    0  31.350         4       0       0          2   4561.18850
# 1130   39    0  23.870         5       0       2          1   8582.30230
# 1294   58    1  25.175         0       0       0          3  11931.12525
# 860    37    0  47.600         2       1       3          2  46113.51100
# 1126   55    1  29.900         0       0       3          3  10214.63600
#
# [1070 rows x 8 columns]

# %% [markdown]
# # selecting rows with loc

# %%
insurance_df.loc[560]
# Out:
# age            46.0000
# sex             0.0000
# bmi            19.9500
# children        2.0000
# smoker          0.0000
# region          1.0000
# BMI_group       1.0000
# charge       9193.8385
# Name: 560, dtype: float64

# %% [markdown]
# # slicing and dicing with loc

# %%
insurance_df.loc[560,"charge"]
# Out:
# 9193.8385

# %%
insurance_df.loc[969,["region","charge"]]
# Out:
# region       2.0000
# charge    8596.8278
# Name: 969, dtype: float64

# %%
insurance_df.loc[:,["bmi","charge"]]
# Out:
#          bmi       charge
# ID
# 560   19.950   9193.83850
# 1285  24.320   8534.67180
# 1142  24.860  27117.99378
# 969   34.320   8596.82780
# 486   21.470  12475.35130
# ...      ...          ...
# 1095  31.350   4561.18850
# 1130  23.870   8582.30230
# 1294  25.175  11931.12525
# 860   47.600  46113.51100
# 1126  29.900  10214.63600
#
# [1070 rows x 2 columns]

# %%
insurance_df.loc[1126,"children":]
# Out:
# children         0.000
# smoker           0.000
# region           3.000
# BMI_group        3.000
# charge       10214.636
# Name: 1126, dtype: float64

# %%
insurance_df.loc[1126,"children":"charge"]
# Out:
# children         0.000
# smoker           0.000
# region           3.000
# BMI_group        3.000
# charge       10214.636
# Name: 1126, dtype: float64

# %%
insurance_df
# Out:
#       age  sex     bmi  children  smoker  region  BMI_group       charge
# ID
# 560    46    0  19.950         2       0       1          1   9193.83850
# 1285   47    0  24.320         0       0       0          1   8534.67180
# 1142   52    0  24.860         0       0       2          1  27117.99378
# 969    39    0  34.320         5       0       2          2   8596.82780
# 486    54    0  21.470         3       0       1          1  12475.35130
# ...   ...  ...     ...       ...     ...     ...        ...          ...
# 1095   18    0  31.350         4       0       0          2   4561.18850
# 1130   39    0  23.870         5       0       2          1   8582.30230
# 1294   58    1  25.175         0       0       0          3  11931.12525
# 860    37    0  47.600         2       1       3          2  46113.51100
# 1126   55    1  29.900         0       0       3          3  10214.63600
#
# [1070 rows x 8 columns]

# %%
type(insurance_df)
# Out:
# pandas.core.frame.DataFrame

# %%
type(insurance_df["bmi"])
# Out:
# pandas.core.series.Series

# %%
type(insurance_df.columns)
# Out:
# pandas.core.indexes.base.Index

# %% [markdown]
# # Pandas series

# %%
bmi = insurance_df["bmi"]

# %%
type(bmi)
# Out:
# pandas.core.series.Series

# %%
bmi.head(5)
# Out:
# ID
# 560     19.95
# 1285    24.32
# 1142    24.86
# 969     34.32
# 486     21.47
# Name: bmi, dtype: float64

# %%
bmi.dtype
# Out:
# dtype('float64')

# %%
len(bmi)
# Out:
# 1070

# %%
bmi.to_frame()
# Out:
#          bmi
# ID
# 560   19.950
# 1285  24.320
# 1142  24.860
# 969   34.320
# 486   21.470
# ...      ...
# 1095  31.350
# 1130  23.870
# 1294  25.175
# 860   47.600
# 1126  29.900
#
# [1070 rows x 1 columns]

# %%
type(bmi.to_frame())
# Out:
# pandas.core.frame.DataFrame

# %%
bmi.to_frame().info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 1070 entries, 560 to 1126
# Data columns (total 1 columns):
# bmi    1070 non-null float64
# dtypes: float64(1)
# memory usage: 56.7 KB

# %%
bmi.describe()
# Out:
# count    1070.000000
# mean       30.560397
# std         6.043386
# min        15.960000
# 25%        26.205000
# 50%        30.210000
# 75%        34.496250
# max        53.130000
# Name: bmi, dtype: float64

# %%
bmi.sum()
# Out:
# 32699.625

# %%
bmi.sum(skipna=False)
# Out:
# 32699.625

# %%
bmi.unique()
# Out:
# array([19.95 , 24.32 , 24.86 , 34.32 , 21.47 , 41.47 , 24.3  , 21.565,
#        41.23 , 34.2  , 22.42 , 37.07 , 29.925, 39.33 , 25.8  , 32.205,
#        33.4  , 26.22 , 37.73 , 41.8  , 27.645, 35.625, 31.92 , 28.1  ,
#        17.955, 24.31 , 24.035, 37.51 , 19.8  , 28.05 , 40.15 , 30.8  ,
#        45.43 , 30.59 , 26.03 , 29.7  , 35.53 , 33.88 , 42.13 , 38.28 ,
#        27.7  , 30.03 , 24.13 , 33.2  , 22.3  , 33.   , 36.48 , 38.39 ,
#        33.82 , 24.42 , 32.6  , 39.8  , 31.4  , 27.72 , 28.7  , 33.11 ,
#        21.5  , 41.325, 39.6  , 27.55 , 34.865, 32.8  , 30.25 , 33.55 ,
#        23.655, 26.51 , 39.7  , 36.08 , 28.9  , 26.315, 26.8  , 30.115,
#        28.27 , 31.35 , 33.7  , 27.74 , 27.   , 23.4  , 33.99 , 34.105,
#        38.17 , 38.06 , 26.62 , 31.02 , 33.3  , 25.27 , 23.94 , 29.92 ,
#        30.5  , 37.335, 22.61 , 33.345, 20.235, 43.7  , 42.94 , 17.4  ,
#        28.785, 28.3  , 32.67 , 30.2  , 40.185, 25.84 , 26.9  , 22.8  ,
# ...

# %%
len(bmi.unique())
# Out:
# 494

# %%
bmi.value_counts()
# Out:
# 32.300    12
# 28.310     9
# 30.495     7
# 30.800     7
# 34.800     7
#           ..
# 31.200     1
# 35.435     1
# 30.690     1
# 27.300     1
# 34.010     1
# Name: bmi, Length: 494, dtype: int64

# %%
bmi.value_counts(sort=False)
# Out:
# 35.625    4
# 33.000    3
# 21.500    1
# 27.000    1
# 30.500    3
#          ..
# 18.715    1
# 35.310    2
# 22.705    3
# 25.365    3
# 34.010    1
# Name: bmi, Length: 494, dtype: int64

# %%
bmi.value_counts(ascending=False)
# Out:
# 32.300    12
# 28.310     9
# 30.495     7
# 30.800     7
# 34.800     7
#           ..
# 31.200     1
# 35.435     1
# 30.690     1
# 27.300     1
# 34.010     1
# Name: bmi, Length: 494, dtype: int64

# %%
len(bmi.notna())
# Out:
# 1070

# %%
insurance_df
# Out:
#       age  sex     bmi  children  smoker  region  BMI_group       charge
# ID
# 560    46    0  19.950         2       0       1          1   9193.83850
# 1285   47    0  24.320         0       0       0          1   8534.67180
# 1142   52    0  24.860         0       0       2          1  27117.99378
# 969    39    0  34.320         5       0       2          2   8596.82780
# 486    54    0  21.470         3       0       1          1  12475.35130
# ...   ...  ...     ...       ...     ...     ...        ...          ...
# 1095   18    0  31.350         4       0       0          2   4561.18850
# 1130   39    0  23.870         5       0       2          1   8582.30230
# 1294   58    1  25.175         0       0       0          3  11931.12525
# 860    37    0  47.600         2       1       3          2  46113.51100
# 1126   55    1  29.900         0       0       3          3  10214.63600
#
# [1070 rows x 8 columns]

# %% [markdown]
# # dropping a column

# %%
insurance_df.drop("region",axis=1)
# Out:
#       age  sex     bmi  children  smoker  BMI_group       charge
# ID
# 560    46    0  19.950         2       0          1   9193.83850
# 1285   47    0  24.320         0       0          1   8534.67180
# 1142   52    0  24.860         0       0          1  27117.99378
# 969    39    0  34.320         5       0          2   8596.82780
# 486    54    0  21.470         3       0          1  12475.35130
# ...   ...  ...     ...       ...     ...        ...          ...
# 1095   18    0  31.350         4       0          2   4561.18850
# 1130   39    0  23.870         5       0          1   8582.30230
# 1294   58    1  25.175         0       0          3  11931.12525
# 860    37    0  47.600         2       1          2  46113.51100
# 1126   55    1  29.900         0       0          3  10214.63600
#
# [1070 rows x 7 columns]

# %%
insurance_df
# Out:
#       age  sex     bmi  children  smoker  region  BMI_group       charge
# ID
# 560    46    0  19.950         2       0       1          1   9193.83850
# 1285   47    0  24.320         0       0       0          1   8534.67180
# 1142   52    0  24.860         0       0       2          1  27117.99378
# 969    39    0  34.320         5       0       2          2   8596.82780
# 486    54    0  21.470         3       0       1          1  12475.35130
# ...   ...  ...     ...       ...     ...     ...        ...          ...
# 1095   18    0  31.350         4       0       0          2   4561.18850
# 1130   39    0  23.870         5       0       2          1   8582.30230
# 1294   58    1  25.175         0       0       0          3  11931.12525
# 860    37    0  47.600         2       1       3          2  46113.51100
# 1126   55    1  29.900         0       0       3          3  10214.63600
#
# [1070 rows x 8 columns]

# %%
# change the value of BMI_group field to 2 for ID=560
insurance_df.loc[560,"BMI_group"]=2

# %%
insurance_df
# Out:
#       age  sex     bmi  children  smoker  region  BMI_group       charge
# ID
# 560    46    0  19.950         2       0       1          2   9193.83850
# 1285   47    0  24.320         0       0       0          1   8534.67180
# 1142   52    0  24.860         0       0       2          1  27117.99378
# 969    39    0  34.320         5       0       2          2   8596.82780
# 486    54    0  21.470         3       0       1          1  12475.35130
# ...   ...  ...     ...       ...     ...     ...        ...          ...
# 1095   18    0  31.350         4       0       0          2   4561.18850
# 1130   39    0  23.870         5       0       2          1   8582.30230
# 1294   58    1  25.175         0       0       0          3  11931.12525
# 860    37    0  47.600         2       1       3          2  46113.51100
# 1126   55    1  29.900         0       0       3          3  10214.63600
#
# [1070 rows x 8 columns]

# %%
#change the value of BMI_group to 3 for ID : 1285,1142,969

#insurance_df.loc[[1285,1142,969],["BMI_group"]] = 3 
insurance_df.loc[1285:969,["BMI_group"]] = 3

# %%
insurance_df
# Out:
#       age  sex     bmi  children  smoker  region  BMI_group       charge
# ID
# 560    46    0  19.950         2       0       1          2   9193.83850
# 1285   47    0  24.320         0       0       0          3   8534.67180
# 1142   52    0  24.860         0       0       2          3  27117.99378
# 969    39    0  34.320         5       0       2          3   8596.82780
# 486    54    0  21.470         3       0       1          1  12475.35130
# ...   ...  ...     ...       ...     ...     ...        ...          ...
# 1095   18    0  31.350         4       0       0          2   4561.18850
# 1130   39    0  23.870         5       0       2          1   8582.30230
# 1294   58    1  25.175         0       0       0          3  11931.12525
# 860    37    0  47.600         2       1       3          2  46113.51100
# 1126   55    1  29.900         0       0       3          3  10214.63600
#
# [1070 rows x 8 columns]

# %%
insurance_df.loc[1285:969,["BMI_Group"]] = 2
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-103-efc6360788f1> in <module>
# ----> 1 insurance_df.loc[1285:969,["BMI_Group"]] = 2
#
# ~/anaconda3/lib/python3.7/site-packages/pandas/core/indexing.py in __setitem__(self, key, value)
#     187         else:
#     188             key = com.apply_if_callable(key, self.obj)
# --> 189         indexer = self._get_setitem_indexer(key)
#     190         self._setitem_with_indexer(indexer, value)
#     191
#
# ~/anaconda3/lib/python3.7/site-packages/pandas/core/indexing.py in _get_setitem_indexer(self, key)
#     165         if isinstance(key, tuple):
#     166             try:
# --> 167                 return self._convert_tuple(key, is_setter=True)
#     168             except IndexingError:
#     169                 pass
#
# ...

# %%
insurance_df
# Out:
#       age  sex     bmi  children  smoker  region  BMI_group       charge
# ID
# 560    46    0  19.950         2       0       1          2   9193.83850
# 1285   47    0  24.320         0       0       0          3   8534.67180
# 1142   52    0  24.860         0       0       2          3  27117.99378
# 969    39    0  34.320         5       0       2          3   8596.82780
# 486    54    0  21.470         3       0       1          1  12475.35130
# ...   ...  ...     ...       ...     ...     ...        ...          ...
# 1095   18    0  31.350         4       0       0          2   4561.18850
# 1130   39    0  23.870         5       0       2          1   8582.30230
# 1294   58    1  25.175         0       0       0          3  11931.12525
# 860    37    0  47.600         2       1       3          2  46113.51100
# 1126   55    1  29.900         0       0       3          3  10214.63600
#
# [1070 rows x 8 columns]

# %%
insurance_df[insurance_df["bmi"]>30]["bmi"]
# Out:
# ID
# 969     34.320
# 170     41.470
# 209     41.230
# 947     34.200
# 1140    37.070
#          ...
# 1123    32.395
# 330     36.385
# 1044    35.245
# 1095    31.350
# 860     47.600
# Name: bmi, Length: 558, dtype: float64

# %%
insurance_df.loc[insurance_df.bmi>30,"bmi"]
# Out:
# ID
# 969     34.320
# 170     41.470
# 209     41.230
# 947     34.200
# 1140    37.070
#          ...
# 1123    32.395
# 330     36.385
# 1044    35.245
# 1095    31.350
# 860     47.600
# Name: bmi, Length: 558, dtype: float64

# %%
insurance_df
# Out:
#       age  sex     bmi  children  smoker  region  BMI_group       charge
# ID
# 560    46    0  19.950         2       0       1          2   9193.83850
# 1285   47    0  24.320         0       0       0          3   8534.67180
# 1142   52    0  24.860         0       0       2          3  27117.99378
# 969    39    0  34.320         5       0       2          3   8596.82780
# 486    54    0  21.470         3       0       1          1  12475.35130
# ...   ...  ...     ...       ...     ...     ...        ...          ...
# 1095   18    0  31.350         4       0       0          2   4561.18850
# 1130   39    0  23.870         5       0       2          1   8582.30230
# 1294   58    1  25.175         0       0       0          3  11931.12525
# 860    37    0  47.600         2       1       3          2  46113.51100
# 1126   55    1  29.900         0       0       3          3  10214.63600
#
# [1070 rows x 8 columns]

# %%
insurance_df["new_column"]=100

# %%
insurance_df
# Out:
#       age  sex     bmi  children  smoker  region  BMI_group       charge  \
# ID
# 560    46    0  19.950         2       0       1          2   9193.83850
# 1285   47    0  24.320         0       0       0          3   8534.67180
# 1142   52    0  24.860         0       0       2          3  27117.99378
# 969    39    0  34.320         5       0       2          3   8596.82780
# 486    54    0  21.470         3       0       1          1  12475.35130
# ...   ...  ...     ...       ...     ...     ...        ...          ...
# 1095   18    0  31.350         4       0       0          2   4561.18850
# 1130   39    0  23.870         5       0       2          1   8582.30230
# 1294   58    1  25.175         0       0       0          3  11931.12525
# 860    37    0  47.600         2       1       3          2  46113.51100
# 1126   55    1  29.900         0       0       3          3  10214.63600
#
#       new_column
# ID
# 560          100
# 1285         100
# 1142         100
# ...

# %%
insurance_df
# Out:
#       age  sex     bmi  children  smoker  region  BMI_group       charge  \
# ID
# 560    46    0  19.950         2       0       1          2   9193.83850
# 1285   47    0  24.320         0       0       0          3   8534.67180
# 1142   52    0  24.860         0       0       2          3  27117.99378
# 969    39    0  34.320         5       0       2          3   8596.82780
# 486    54    0  21.470         3       0       1          1  12475.35130
# ...   ...  ...     ...       ...     ...     ...        ...          ...
# 1095   18    0  31.350         4       0       0          2   4561.18850
# 1130   39    0  23.870         5       0       2          1   8582.30230
# 1294   58    1  25.175         0       0       0          3  11931.12525
# 860    37    0  47.600         2       1       3          2  46113.51100
# 1126   55    1  29.900         0       0       3          3  10214.63600
#
#       new_column
# ID
# 560          100
# 1285         100
# 1142         100
# ...

# %%
# bmi>30 and age >50

insurance_df.loc[((insurance_df.region> 1) & (insurance_df.age>30)),'bmi']
# Out:
# ID
# 1142    24.86
# 969     34.32
# 170     41.47
# 1140    37.07
# 932     25.80
#         ...
# 87      27.20
# 466     28.70
# 1130    23.87
# 860     47.60
# 1126    29.90
# Name: bmi, Length: 371, dtype: float64
